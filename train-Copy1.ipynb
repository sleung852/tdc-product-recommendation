# %%
import pandas as pd
import numpy as np
from model.gmf import GMFEngine
from model.mlp import MLPEngine
from model.neumf import NeuMFEngine
from data import SampleGenerator
import os

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# DataLoader for training
thepath=os.path.join('data','user-item-oct-dec-2018-v2-modified.csv')
sample_generator = SampleGenerator(thepath)
# Out:
# Initialising data cleaning
# Number of bad users: 75054
# Number of bad items: 72173
# Starting clean process 1
#
# Number of bad users: 5553
# Number of bad items: 7677
# Starting clean process 2
#
# Number of bad users: 1542
# Number of bad items: 1906
# Starting clean process 3
#
# Number of bad users: 465
# Number of bad items: 672
# Starting clean process 4
#
# Number of bad users: 199
# Number of bad items: 243
# Starting clean process 5
#
# Number of bad users: 66
# Number of bad items: 104
# Starting clean process 6
#
# Number of bad users: 32
# Number of bad items: 40
# Starting clean process 7
#
# Number of bad users: 9
# Number of bad items: 19
# Starting clean process 8
#
# Number of bad users: 5
# Number of bad items: 4
# Starting clean process 9
#
# Number of bad users: 3
# Number of bad items: 4
# Starting clean process 10
#
# Number of bad users: 1
# Number of bad items: 3
# Starting clean process 11
#
# Number of bad users: 1
# Number of bad items: 1
# Starting clean process 12
#
# Number of bad users: 1
# Number of bad items: 1
# Starting clean process 13
#
# Number of bad users: 0
# Number of bad items: 1
# Starting clean process 14
#
# Number of bad users: 1
# Number of bad items: 0
# Starting clean process 15
#
# No more rubbish data.
# Range of userId is [0, 11410]
# Range of itemId is [0, 13202]
# userId         int64
# itemId         int64
# rating         int32
# timestamp    float64
# dtype: object
# userId
# 2126    1
# 0       2
# 6843    2
# 6840    2
# 6839    2
# Name: itemId, dtype: int64
# found 1 useless datapoints
# data cleaned!
#
# Initialising data pre-processing
# begin preprocess_ratings
# begin setting pools
# creating negative items
# 0
#   3%|▎         | 330/11410 [00:00<00:03, 3292.80it/s]
# 1
# 100%|██████████| 11410/11410 [00:05<00:00, 2117.05it/s]
#   2%|▏         | 254/11410 [00:00<00:05, 2143.57it/s]
# 2
# 100%|██████████| 11410/11410 [00:03<00:00, 3585.30it/s]
# split_loo
# train user n unique: 11410
# test user n unique: 11410
# Done!

# %%
evaluate_data = sample_generator.evaluate_data
# Out:
# Begin the loop...

# %%
num_itemid, num_userid = sample_generator.usr_item_unique()

# %%
num_itemid
# Out:
# 13203

# %%
num_userid
# Out:
# 11410

# %%
# Training Engine
def train_model(model, config):
    engine = model(config)
    best_hit = 0
    for epoch in range(config['num_epoch']):
        print('Epoch {} starts !'.format(epoch))
        print('-' * 70)
        train_loader = sample_generator.instance_a_train_loader(config['num_negative'], config['batch_size'])
        engine.train_an_epoch(train_loader, epoch_id=epoch)
        hit_ratio, ndcg = engine.evaluate(evaluate_data, epoch_id=epoch)
        if epoch % 20 == 0:
            engine.save(config['alias'], epoch, hit_ratio, ndcg)
        elif (epoch == config['num_epoch'] - 1):
            engine.save(config['alias'], epoch, hit_ratio, ndcg)
        if hit_ratio > best_hit:
            best_hit = hit_ratio
            engine.save(config['alias'], epoch, hit_ratio, ndcg, backup=False)

# %%
#setup configuration for GMF
gmf_config = {'alias': 'gmf_factor8neg4-implict',
              'num_epoch': 200,
              'batch_size': 4,
              # 'optimizer': 'sgd',
              # 'sgd_lr': 1e-3,
              # 'sgd_momentum': 0.9,
              # 'optimizer': 'rmsprop',
              # 'rmsprop_lr': 1e-3,
              # 'rmsprop_alpha': 0.99,
              # 'rmsprop_momentum': 0,
              'optimizer': 'adam',
              'adam_lr': 1e-3,
              'num_users': num_userid,
              'num_items': num_itemid,
              'latent_dim': 8,
              'num_negative': 4,
              'l2_regularization': 0, # 0.01
              'use_cuda': True,
              'device_id': 0,
              'model_dir':'checkpoints/{}_Epoch{}_HR{:.4f}_NDCG{:.4f}.model'}

# %%
# Train GMF Model
train_model(GMFEngine, gmf_config)
# Out:
# Epoch 0 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 0] Loss 0.5944649577140808
# /home/ec2-user/SageMaker/tdc-product-recommendation/metrics.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_in_top_k['ndcg'] = test_in_top_k['rank'].apply(lambda x: math.log(2) / math.log(1 + x)) # the rank starts from 1
# [Evaluating Epoch 0] HR = 0.0940, NDCG = 0.0430
#
# Epoch 1 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 1] Loss 0.5706994533538818
# [Evaluating Epoch 1] HR = 0.1037, NDCG = 0.0477
#
# Epoch 2 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 2] Loss 0.22941476106643677
# [Evaluating Epoch 2] HR = 0.1019, NDCG = 0.0457
#
# Epoch 3 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 3] Loss 0.5677672028541565
# [Evaluating Epoch 3] HR = 0.1054, NDCG = 0.0478
#
# Epoch 4 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 4] Loss 0.5617380738258362
# [Evaluating Epoch 4] HR = 0.1079, NDCG = 0.0499
#
# Epoch 5 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 5] Loss 0.5944874882698059
# [Evaluating Epoch 5] HR = 0.1098, NDCG = 0.0520
#
# Epoch 6 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 6] Loss 0.2285344898700714
# [Evaluating Epoch 6] HR = 0.1112, NDCG = 0.0530
#
# Epoch 7 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 7] Loss 0.24365580081939697
# [Evaluating Epoch 7] HR = 0.1130, NDCG = 0.0553
#
# Epoch 8 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 8] Loss 0.6704994440078735
# [Evaluating Epoch 8] HR = 0.1193, NDCG = 0.0587
#
# Epoch 9 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 9] Loss 0.24679584801197052
# [Evaluating Epoch 9] HR = 0.1227, NDCG = 0.0608
#
# Epoch 10 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 10] Loss 0.30969640612602234
# [Evaluating Epoch 10] HR = 0.1258, NDCG = 0.0637
#
# Epoch 11 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 11] Loss 0.8579373955726624
# [Evaluating Epoch 11] HR = 0.1286, NDCG = 0.0666
#
# Epoch 12 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 12] Loss 0.4386613965034485
# [Evaluating Epoch 12] HR = 0.1299, NDCG = 0.0676
#
# Epoch 13 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 13] Loss 0.19482555985450745
# [Evaluating Epoch 13] HR = 0.1330, NDCG = 0.0701
#
# Epoch 14 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 14] Loss 0.2891295850276947
# [Evaluating Epoch 14] HR = 0.1325, NDCG = 0.0705
#
# Epoch 15 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 15] Loss 0.12077491730451584
# [Evaluating Epoch 15] HR = 0.1343, NDCG = 0.0731
#
# Epoch 16 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 16] Loss 0.05104893818497658
# [Evaluating Epoch 16] HR = 0.1393, NDCG = 0.0754
#
# Epoch 17 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 17] Loss 0.43119335174560547
# [Evaluating Epoch 17] HR = 0.1404, NDCG = 0.0776
#
# Epoch 18 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 18] Loss 0.31491798162460327
# [Evaluating Epoch 18] HR = 0.1391, NDCG = 0.0775
#
# Epoch 19 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 19] Loss 0.784656286239624
# [Evaluating Epoch 19] HR = 0.1438, NDCG = 0.0805
#
# Epoch 20 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 20] Loss 0.17158478498458862
# [Evaluating Epoch 20] HR = 0.1472, NDCG = 0.0838
#
# Epoch 21 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 21] Loss 0.40712741017341614
# [Evaluating Epoch 21] HR = 0.1502, NDCG = 0.0852
#
# Epoch 22 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 22] Loss 0.4169262647628784
# [Evaluating Epoch 22] HR = 0.1494, NDCG = 0.0858
#
# Epoch 23 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 23] Loss 0.5107202529907227
# [Evaluating Epoch 23] HR = 0.1559, NDCG = 0.0898
#
# Epoch 24 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 24] Loss 0.23868967592716217
# [Evaluating Epoch 24] HR = 0.1555, NDCG = 0.0906
#
# Epoch 25 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 25] Loss 0.03837636113166809
# [Evaluating Epoch 25] HR = 0.1553, NDCG = 0.0907
#
# Epoch 26 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 26] Loss 0.459927499294281
# [Evaluating Epoch 26] HR = 0.1569, NDCG = 0.0926
#
# Epoch 27 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 27] Loss 0.36386337876319885
# [Evaluating Epoch 27] HR = 0.1599, NDCG = 0.0954
#
# Epoch 28 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 28] Loss 0.1957894116640091
# [Evaluating Epoch 28] HR = 0.1616, NDCG = 0.0968
#
# Epoch 29 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 29] Loss 0.26903268694877625
# [Evaluating Epoch 29] HR = 0.1644, NDCG = 0.0982
#
# Epoch 30 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 30] Loss 0.21183359622955322
# [Evaluating Epoch 30] HR = 0.1666, NDCG = 0.0997
#
# Epoch 31 starts !
# ----------------------------------------------------------------------

# %%
mlp_config = {'alias': 'mlp_factor8neg4_bz256_166432168_pretrain_reg_0.0000001',
              'num_epoch': 200,
              'batch_size': 4,  # 1024,
              'optimizer': 'adam',
              'adam_lr': 1e-3,
              'num_users': num_userid,
              'num_items': num_itemid,
              'latent_dim': 8,
              'num_negative': 4,
              'layers': [16,64,32,16,8],  # layers[0] is the concat of latent user vector & latent item vector
              'l2_regularization': 0.0000001,  # MLP model is sensitive to hyper params
              'use_cuda': True,
              'device_id': 0,
              'pretrain': True,
              'pretrain_mf': 'gmf_factor8neg4-implict_best.model',
              'model_dir':'checkpoints/{}_Epoch{}_HR{:.4f}_NDCG{:.4f}.model'}

# %%
train_model(MLPEngine, mlp_config)
#need to add a learning rate scheduler
# Out:
# MLP(
#   (embedding_user): Embedding(11411, 8)
#   (embedding_item): Embedding(13203, 8)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (affine_output): Linear(in_features=8, out_features=1, bias=True)
#   (logistic): Sigmoid()
# )
# Epoch 0 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 0] Loss 0.3539768159389496
# /home/ec2-user/SageMaker/tdc-product-recommendation/metrics.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_in_top_k['ndcg'] = test_in_top_k['rank'].apply(lambda x: math.log(2) / math.log(1 + x)) # the rank starts from 1
# [Evaluating Epoch 0] HR = 0.2777, NDCG = 0.1935
#
# Epoch 1 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 1] Loss 0.7906252145767212
# [Evaluating Epoch 1] HR = 0.2894, NDCG = 0.2020
#
# Epoch 2 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 2] Loss 0.9205023050308228
# [Evaluating Epoch 2] HR = 0.2815, NDCG = 0.1973
#
# Epoch 3 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 3] Loss 0.2467784285545349
# [Evaluating Epoch 3] HR = 0.2856, NDCG = 0.1999
#
# Epoch 4 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 4] Loss 0.21626172959804535
# [Evaluating Epoch 4] HR = 0.2894, NDCG = 0.1993
#
# Epoch 5 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 5] Loss 0.7835968732833862
# [Evaluating Epoch 5] HR = 0.2901, NDCG = 0.2022
#
# Epoch 6 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 6] Loss 0.2158716320991516
# [Evaluating Epoch 6] HR = 0.2920, NDCG = 0.2027
#
# Epoch 7 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 7] Loss 0.3588429093360901
# [Evaluating Epoch 7] HR = 0.2945, NDCG = 0.2034
#
# Epoch 8 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 8] Loss 0.31993794441223145
# [Evaluating Epoch 8] HR = 0.2891, NDCG = 0.2024
#
# Epoch 9 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 9] Loss 0.21026337146759033
# [Evaluating Epoch 9] HR = 0.2838, NDCG = 0.1950
#
# Epoch 10 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 10] Loss 0.16198605298995972
# [Evaluating Epoch 10] HR = 0.2876, NDCG = 0.2003
#
# Epoch 11 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 11] Loss 0.23956787586212158
# [Evaluating Epoch 11] HR = 0.2960, NDCG = 0.2013
#
# Epoch 12 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 12] Loss 0.1382538229227066
# [Evaluating Epoch 12] HR = 0.2969, NDCG = 0.2051
#
# Epoch 13 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 13] Loss 0.6327922940254211
# [Evaluating Epoch 13] HR = 0.2918, NDCG = 0.2024
#
# Epoch 14 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 14] Loss 0.20993167161941528
# [Evaluating Epoch 14] HR = 0.2980, NDCG = 0.2058
#
# Epoch 15 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 15] Loss 0.3691757917404175
# [Evaluating Epoch 15] HR = 0.2965, NDCG = 0.2058
#
# Epoch 16 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 16] Loss 0.1001625508069992
# [Evaluating Epoch 16] HR = 0.2929, NDCG = 0.2027
#
# Epoch 17 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 17] Loss 0.4183289110660553
# [Evaluating Epoch 17] HR = 0.2935, NDCG = 0.2008
#
# Epoch 18 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 18] Loss 0.276164710521698
# [Evaluating Epoch 18] HR = 0.2933, NDCG = 0.2022
#
# Epoch 19 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 19] Loss 0.6006330847740173
# [Evaluating Epoch 19] HR = 0.2961, NDCG = 0.2034
#
# Epoch 20 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 20] Loss 0.5177062749862671
# [Evaluating Epoch 20] HR = 0.2952, NDCG = 0.2020
#
# Epoch 21 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 21] Loss 0.697785496711731
# [Evaluating Epoch 21] HR = 0.2897, NDCG = 0.1962
#
# Epoch 22 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 22] Loss 0.7934316992759705
# [Evaluating Epoch 22] HR = 0.2913, NDCG = 0.1987
#
# Epoch 23 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 23] Loss 0.12430389970541
# [Evaluating Epoch 23] HR = 0.2874, NDCG = 0.1979
#
# Epoch 24 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 24] Loss 0.047269195318222046
# [Evaluating Epoch 24] HR = 0.2882, NDCG = 0.2006
#
# Epoch 25 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 25] Loss 0.44201743602752686
# [Evaluating Epoch 25] HR = 0.2925, NDCG = 0.2006
#
# Epoch 26 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 26] Loss 0.06149478629231453
# [Evaluating Epoch 26] HR = 0.2945, NDCG = 0.1981
#
# Epoch 27 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 27] Loss 0.09536480903625488
# [Evaluating Epoch 27] HR = 0.3011, NDCG = 0.2043
#
# Epoch 28 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 28] Loss 0.0644056499004364
# [Evaluating Epoch 28] HR = 0.2962, NDCG = 0.2001
#
# Epoch 29 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 29] Loss 0.47696107625961304
# [Evaluating Epoch 29] HR = 0.2991, NDCG = 0.2025
#
# Epoch 30 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 30] Loss 0.6410120725631714
# [Evaluating Epoch 30] HR = 0.2984, NDCG = 0.2033
#
# Epoch 31 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 31] Loss 0.12553364038467407
# [Evaluating Epoch 31] HR = 0.2981, NDCG = 0.2046
#
# Epoch 32 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 32] Loss 0.13637851178646088
# [Evaluating Epoch 32] HR = 0.2944, NDCG = 0.2020
#
# Epoch 33 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 33] Loss 0.11194559931755066
# [Evaluating Epoch 33] HR = 0.2994, NDCG = 0.2036
#
# Epoch 34 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 34] Loss 0.2131752073764801
# [Evaluating Epoch 34] HR = 0.2966, NDCG = 0.2049
#
# Epoch 35 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 35] Loss 0.3784502148628235
# [Evaluating Epoch 35] HR = 0.2990, NDCG = 0.2021
#
# Epoch 36 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 36] Loss 0.5242899656295776
# [Evaluating Epoch 36] HR = 0.2973, NDCG = 0.2033
#
# Epoch 37 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 37] Loss 0.5991255640983582
# [Evaluating Epoch 37] HR = 0.2998, NDCG = 0.2005
#
# Epoch 38 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 38] Loss 0.1276915967464447
# [Evaluating Epoch 38] HR = 0.3026, NDCG = 0.2066
#
# Epoch 39 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 39] Loss 0.6455514430999756
# [Evaluating Epoch 39] HR = 0.2952, NDCG = 0.2011
#
# Epoch 40 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 40] Loss 0.13749775290489197
# [Evaluating Epoch 40] HR = 0.2997, NDCG = 0.2018
#
# Epoch 41 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 41] Loss 0.11086484044790268
# [Evaluating Epoch 41] HR = 0.2974, NDCG = 0.2025
#
# Epoch 42 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 42] Loss 0.05506584793329239
# [Evaluating Epoch 42] HR = 0.2980, NDCG = 0.2014
#
# Epoch 43 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 43] Loss 0.3387586176395416
# [Evaluating Epoch 43] HR = 0.3013, NDCG = 0.2035
#
# Epoch 44 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 44] Loss 0.44563227891921997
# [Evaluating Epoch 44] HR = 0.2905, NDCG = 0.2004
#
# Epoch 45 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 45] Loss 0.41291603446006775
# [Evaluating Epoch 45] HR = 0.2949, NDCG = 0.2008
#
# Epoch 46 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 46] Loss 0.6591451168060303
# [Evaluating Epoch 46] HR = 0.2901, NDCG = 0.1965
#
# Epoch 47 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 47] Loss 0.43042346835136414
# [Evaluating Epoch 47] HR = 0.2976, NDCG = 0.2048
#
# Epoch 48 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 48] Loss 0.26253604888916016
# [Evaluating Epoch 48] HR = 0.3046, NDCG = 0.2066
#
# Epoch 49 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 49] Loss 0.6797062158584595
# [Evaluating Epoch 49] HR = 0.2997, NDCG = 0.2000
#
# Epoch 50 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 50] Loss 0.7411882877349854
# [Evaluating Epoch 50] HR = 0.2992, NDCG = 0.2026
#
# Epoch 51 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 51] Loss 0.5967589020729065
# [Evaluating Epoch 51] HR = 0.3010, NDCG = 0.2065
#
# Epoch 52 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 52] Loss 1.2355105876922607
# [Evaluating Epoch 52] HR = 0.2995, NDCG = 0.2059
#
# Epoch 53 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 53] Loss 0.45481762290000916
# [Evaluating Epoch 53] HR = 0.3024, NDCG = 0.2083
#
# Epoch 54 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 54] Loss 0.6924726963043213
# [Evaluating Epoch 54] HR = 0.2991, NDCG = 0.2059
#
# Epoch 55 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 55] Loss 0.06581832468509674
# [Evaluating Epoch 55] HR = 0.3001, NDCG = 0.2037
#
# Epoch 56 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 56] Loss 0.10444361716508865
# [Evaluating Epoch 56] HR = 0.3038, NDCG = 0.2083
#
# Epoch 57 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 57] Loss 0.15473023056983948
# [Evaluating Epoch 57] HR = 0.3028, NDCG = 0.2078
#
# Epoch 58 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 58] Loss 0.09695621579885483
# [Evaluating Epoch 58] HR = 0.2992, NDCG = 0.2036
#
# Epoch 59 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 59] Loss 0.15150600671768188
# [Evaluating Epoch 59] HR = 0.2996, NDCG = 0.2044
#
# Epoch 60 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 60] Loss 0.47575843334198
# [Evaluating Epoch 60] HR = 0.3033, NDCG = 0.2084
#
# Epoch 61 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 61] Loss 0.6869148015975952
# [Evaluating Epoch 61] HR = 0.2970, NDCG = 0.2020
#
# Epoch 62 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 62] Loss 0.7889033555984497
# [Evaluating Epoch 62] HR = 0.3002, NDCG = 0.2075
#
# Epoch 63 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 63] Loss 0.22386009991168976
# [Evaluating Epoch 63] HR = 0.2976, NDCG = 0.2051
#
# Epoch 64 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 64] Loss 0.02109229564666748
# [Evaluating Epoch 64] HR = 0.3068, NDCG = 0.2131
#
# Epoch 65 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 65] Loss 0.1792595386505127
# [Evaluating Epoch 65] HR = 0.2997, NDCG = 0.2046
#
# Epoch 66 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 66] Loss 0.442516028881073
# [Evaluating Epoch 66] HR = 0.2987, NDCG = 0.2037
#
# Epoch 67 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 67] Loss 0.07158252596855164
# [Evaluating Epoch 67] HR = 0.2948, NDCG = 0.1977
#
# Epoch 68 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 68] Loss 0.029619459062814713
# [Evaluating Epoch 68] HR = 0.2929, NDCG = 0.2028
#
# Epoch 69 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 69] Loss 0.19535931944847107
# [Evaluating Epoch 69] HR = 0.2969, NDCG = 0.1966
#
# Epoch 70 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 70] Loss 0.36534786224365234
# [Evaluating Epoch 70] HR = 0.2996, NDCG = 0.2053
#
# Epoch 71 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 71] Loss 0.4519762098789215
# [Evaluating Epoch 71] HR = 0.2977, NDCG = 0.2058
#
# Epoch 72 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 72] Loss 0.23371605575084686
# [Evaluating Epoch 72] HR = 0.2975, NDCG = 0.2059
#
# Epoch 73 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 73] Loss 0.0929473415017128
# [Evaluating Epoch 73] HR = 0.2964, NDCG = 0.2022
#
# Epoch 74 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 74] Loss 0.12428266555070877
# [Evaluating Epoch 74] HR = 0.2980, NDCG = 0.2028
#
# Epoch 75 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 75] Loss 0.7838965654373169
# [Evaluating Epoch 75] HR = 0.2975, NDCG = 0.2030
#
# Epoch 76 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 76] Loss 0.17373639345169067
# [Evaluating Epoch 76] HR = 0.2975, NDCG = 0.1989
#
# Epoch 77 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 77] Loss 0.27392011880874634
# [Evaluating Epoch 77] HR = 0.2986, NDCG = 0.1992
#
# Epoch 78 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 78] Loss 0.7150609493255615
# [Evaluating Epoch 78] HR = 0.2952, NDCG = 0.1992
#
# Epoch 79 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 79] Loss 0.029079724103212357
# [Evaluating Epoch 79] HR = 0.3018, NDCG = 0.2055
#
# Epoch 80 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 80] Loss 0.5996061563491821
# [Evaluating Epoch 80] HR = 0.2988, NDCG = 0.2048
#
# Epoch 81 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 81] Loss 0.04024166241288185
# [Evaluating Epoch 81] HR = 0.2948, NDCG = 0.2025
#
# Epoch 82 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 82] Loss 0.7327582240104675
# [Evaluating Epoch 82] HR = 0.2920, NDCG = 0.2023
#
# Epoch 83 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 83] Loss 0.45904460549354553
# [Evaluating Epoch 83] HR = 0.2945, NDCG = 0.2049
#
# Epoch 84 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 84] Loss 0.26852869987487793
# [Evaluating Epoch 84] HR = 0.2864, NDCG = 0.1985
#
# Epoch 85 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 85] Loss 0.36516302824020386
# [Evaluating Epoch 85] HR = 0.2931, NDCG = 0.2003
#
# Epoch 86 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 86] Loss 0.08051742613315582
# [Evaluating Epoch 86] HR = 0.2893, NDCG = 0.2006
#
# Epoch 87 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 87] Loss 0.25054019689559937
# [Evaluating Epoch 87] HR = 0.2853, NDCG = 0.1933
#
# Epoch 88 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 88] Loss 0.34051835536956787
# [Evaluating Epoch 88] HR = 0.2912, NDCG = 0.2026
#
# Epoch 89 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 89] Loss 0.7296736836433411
# [Evaluating Epoch 89] HR = 0.2910, NDCG = 0.2022
#
# Epoch 90 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 90] Loss 0.7484243512153625
# [Evaluating Epoch 90] HR = 0.2898, NDCG = 0.1997
#
# Epoch 91 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 91] Loss 0.11499305814504623
# [Evaluating Epoch 91] HR = 0.2946, NDCG = 0.2043
#
# Epoch 92 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 92] Loss 0.036611296236515045
# [Evaluating Epoch 92] HR = 0.2914, NDCG = 0.2008
#
# Epoch 93 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 93] Loss 0.20216956734657288
# [Evaluating Epoch 93] HR = 0.2853, NDCG = 0.1966
#
# Epoch 94 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 94] Loss 0.14516286551952362
# [Evaluating Epoch 94] HR = 0.2828, NDCG = 0.2010
#
# Epoch 95 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 95] Loss 0.061870139092206955
# [Evaluating Epoch 95] HR = 0.2856, NDCG = 0.1997
#
# Epoch 96 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 96] Loss 0.06788738071918488
# [Evaluating Epoch 96] HR = 0.2838, NDCG = 0.2025
#
# Epoch 97 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 97] Loss 1.152775526046753
# [Evaluating Epoch 97] HR = 0.2909, NDCG = 0.2028
#
# Epoch 98 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 98] Loss 0.45826879143714905
# [Evaluating Epoch 98] HR = 0.2782, NDCG = 0.1950
#
# Epoch 99 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 99] Loss 0.21472129225730896
# [Evaluating Epoch 99] HR = 0.2862, NDCG = 0.1953
#
# Epoch 100 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 100] Loss 0.6121002435684204
# [Evaluating Epoch 100] HR = 0.2567, NDCG = 0.1739
#
# Epoch 101 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 101] Loss 0.15096712112426758
# [Evaluating Epoch 101] HR = 0.2902, NDCG = 0.2005
#
# Epoch 102 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 102] Loss 0.2075752466917038
# [Evaluating Epoch 102] HR = 0.2838, NDCG = 0.1978
#
# Epoch 103 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 103] Loss 0.1882346272468567
# [Evaluating Epoch 103] HR = 0.2847, NDCG = 0.1982
#
# Epoch 104 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 104] Loss 0.304349422454834
# [Evaluating Epoch 104] HR = 0.2804, NDCG = 0.1959
#
# Epoch 105 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 105] Loss 0.40961557626724243
# [Evaluating Epoch 105] HR = 0.2872, NDCG = 0.2008
#
# Epoch 106 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 106] Loss 0.0971180722117424
# [Evaluating Epoch 106] HR = 0.2778, NDCG = 0.1877
#
# Epoch 107 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 107] Loss 0.25379809737205505
# [Evaluating Epoch 107] HR = 0.2793, NDCG = 0.1969
#
# Epoch 108 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 108] Loss 0.815935492515564
# [Evaluating Epoch 108] HR = 0.2936, NDCG = 0.2005
#
# Epoch 109 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 109] Loss 0.4383822977542877
# [Evaluating Epoch 109] HR = 0.2867, NDCG = 0.1991
#
# Epoch 110 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 110] Loss 0.11792758107185364
# [Evaluating Epoch 110] HR = 0.2860, NDCG = 0.1948
#
# Epoch 111 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 111] Loss 0.11010383814573288
# [Evaluating Epoch 111] HR = 0.2867, NDCG = 0.2015
#
# Epoch 112 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 112] Loss 1.0801270008087158
# [Evaluating Epoch 112] HR = 0.2874, NDCG = 0.1997
#
# Epoch 113 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 113] Loss 0.7938939332962036
# [Evaluating Epoch 113] HR = 0.2887, NDCG = 0.2037
#
# Epoch 114 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 114] Loss 0.1050308495759964
# [Evaluating Epoch 114] HR = 0.2804, NDCG = 0.1967
#
# Epoch 115 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 115] Loss 0.1710919439792633
# [Evaluating Epoch 115] HR = 0.2867, NDCG = 0.2006
#
# Epoch 116 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 116] Loss 0.841768741607666
# [Evaluating Epoch 116] HR = 0.2735, NDCG = 0.1939
#
# Epoch 117 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 117] Loss 0.08119989931583405
# [Evaluating Epoch 117] HR = 0.2857, NDCG = 0.1950
#
# Epoch 118 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 118] Loss 0.13267570734024048
# [Evaluating Epoch 118] HR = 0.2861, NDCG = 0.2004
#
# Epoch 119 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 119] Loss 0.21499158442020416
# [Evaluating Epoch 119] HR = 0.2886, NDCG = 0.2017
#
# Epoch 120 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 120] Loss 1.293664813041687
# [Evaluating Epoch 120] HR = 0.2846, NDCG = 0.1956
#
# Epoch 121 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 121] Loss 0.1468941867351532
# [Evaluating Epoch 121] HR = 0.2853, NDCG = 0.1998
#
# Epoch 122 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 122] Loss 0.09273014962673187
# [Evaluating Epoch 122] HR = 0.2896, NDCG = 0.2019
#
# Epoch 123 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 123] Loss 1.5931737422943115
# [Evaluating Epoch 123] HR = 0.2831, NDCG = 0.2007
#
# Epoch 124 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 124] Loss 0.8355164527893066
# [Evaluating Epoch 124] HR = 0.2829, NDCG = 0.2002
#
# Epoch 125 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 125] Loss 0.39208245277404785
# [Evaluating Epoch 125] HR = 0.2709, NDCG = 0.1970
#
# Epoch 126 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 126] Loss 0.052131716161966324
# [Evaluating Epoch 126] HR = 0.2839, NDCG = 0.2005
#
# Epoch 127 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 127] Loss 0.8476825952529907
# [Evaluating Epoch 127] HR = 0.2432, NDCG = 0.1413
#
# Epoch 128 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 128] Loss 0.6724371314048767
# [Evaluating Epoch 128] HR = 0.2830, NDCG = 0.1999
#
# Epoch 129 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 129] Loss 0.38145163655281067
# [Evaluating Epoch 129] HR = 0.2796, NDCG = 0.1972
#
# Epoch 130 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 130] Loss 0.12103819847106934
# [Evaluating Epoch 130] HR = 0.2828, NDCG = 0.1987
#
# Epoch 131 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 131] Loss 0.21749499440193176
# [Evaluating Epoch 131] HR = 0.2852, NDCG = 0.2013
#
# Epoch 132 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 132] Loss 0.10274486988782883
# [Evaluating Epoch 132] HR = 0.2860, NDCG = 0.2009
#
# Epoch 133 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 133] Loss 0.049858611077070236
# [Evaluating Epoch 133] HR = 0.2912, NDCG = 0.2025
#
# Epoch 134 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 134] Loss 0.5141432285308838
# [Evaluating Epoch 134] HR = 0.2743, NDCG = 0.1981
#
# Epoch 135 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 135] Loss 0.4199206233024597
# [Evaluating Epoch 135] HR = 0.2804, NDCG = 0.1962
#
# Epoch 136 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 136] Loss 0.11480504274368286
# [Evaluating Epoch 136] HR = 0.2851, NDCG = 0.1939
#
# Epoch 137 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 137] Loss 0.7890080213546753
# [Evaluating Epoch 137] HR = 0.2931, NDCG = 0.2023
#
# Epoch 138 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 138] Loss 0.698314368724823
# [Evaluating Epoch 138] HR = 0.2779, NDCG = 0.1995
#
# Epoch 139 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 139] Loss 0.30927711725234985
# [Evaluating Epoch 139] HR = 0.2797, NDCG = 0.1966
#
# Epoch 140 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 140] Loss 0.30912649631500244
# [Evaluating Epoch 140] HR = 0.2883, NDCG = 0.2028
#
# Epoch 141 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 141] Loss 0.06704272329807281
# [Evaluating Epoch 141] HR = 0.2899, NDCG = 0.2025
#
# Epoch 142 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 142] Loss 0.30691397190093994
# [Evaluating Epoch 142] HR = 0.2860, NDCG = 0.2003
#
# Epoch 143 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 143] Loss 0.21127425134181976
# [Evaluating Epoch 143] HR = 0.2891, NDCG = 0.2025
#
# Epoch 144 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 144] Loss 1.0781443119049072
# [Evaluating Epoch 144] HR = 0.2654, NDCG = 0.1945
#
# Epoch 145 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 145] Loss 0.03669174760580063
# [Evaluating Epoch 145] HR = 0.2915, NDCG = 0.2029
#
# Epoch 146 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 146] Loss 0.16500601172447205
# [Evaluating Epoch 146] HR = 0.2873, NDCG = 0.1998
#
# Epoch 147 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 147] Loss 0.14963868260383606
# [Evaluating Epoch 147] HR = 0.2857, NDCG = 0.1990
#
# Epoch 148 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 148] Loss 0.4659520387649536
# [Evaluating Epoch 148] HR = 0.2858, NDCG = 0.2001
#
# Epoch 149 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 149] Loss 0.10904136300086975
# [Evaluating Epoch 149] HR = 0.2905, NDCG = 0.1670
#
# Epoch 150 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 150] Loss 0.07262258231639862
# [Evaluating Epoch 150] HR = 0.2818, NDCG = 0.1812
#
# Epoch 151 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 151] Loss 0.13989931344985962
# [Evaluating Epoch 151] HR = 0.2780, NDCG = 0.1770
#
# Epoch 152 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 152] Loss 0.9610099792480469
# [Evaluating Epoch 152] HR = 0.2864, NDCG = 0.1988
#
# Epoch 153 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 153] Loss 0.2002216875553131
# [Evaluating Epoch 153] HR = 0.2881, NDCG = 0.1987
#
# Epoch 154 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 154] Loss 1.235071063041687
# [Evaluating Epoch 154] HR = 0.2913, NDCG = 0.1956
#
# Epoch 155 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 155] Loss 0.43533650040626526
# [Evaluating Epoch 155] HR = 0.2910, NDCG = 0.1751
#
# Epoch 156 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 156] Loss 0.12429726123809814
# [Evaluating Epoch 156] HR = 0.2925, NDCG = 0.1890
#
# Epoch 157 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 157] Loss 0.3380666673183441
# [Evaluating Epoch 157] HR = 0.2940, NDCG = 0.1602
#
# Epoch 158 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 158] Loss 0.2452615201473236
# [Evaluating Epoch 158] HR = 0.3021, NDCG = 0.2065
#
# Epoch 159 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 159] Loss 0.21531681716442108
# [Evaluating Epoch 159] HR = 0.2913, NDCG = 0.1887
#
# Epoch 160 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 160] Loss 0.7957789301872253
# [Evaluating Epoch 160] HR = 0.2909, NDCG = 0.1984
#
# Epoch 161 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 161] Loss 0.12123333662748337
# [Evaluating Epoch 161] HR = 0.2874, NDCG = 0.1836
#
# Epoch 162 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 162] Loss 0.10087360441684723
# [Evaluating Epoch 162] HR = 0.2870, NDCG = 0.1942
#
# Epoch 163 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 163] Loss 0.8677998185157776
# [Evaluating Epoch 163] HR = 0.2978, NDCG = 0.1934
#
# Epoch 164 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 164] Loss 0.21779848635196686
# [Evaluating Epoch 164] HR = 0.2926, NDCG = 0.1950
#
# Epoch 165 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 165] Loss 0.16196465492248535
# [Evaluating Epoch 165] HR = 0.2959, NDCG = 0.2024
#
# Epoch 166 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 166] Loss 0.4447633624076843
# [Evaluating Epoch 166] HR = 0.2965, NDCG = 0.1998
#
# Epoch 167 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 167] Loss 0.41045254468917847
# [Evaluating Epoch 167] HR = 0.2956, NDCG = 0.1718
#
# Epoch 168 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 168] Loss 0.5845762491226196
# [Evaluating Epoch 168] HR = 0.2928, NDCG = 0.2042
#
# Epoch 169 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 169] Loss 0.1625700145959854
# [Evaluating Epoch 169] HR = 0.2918, NDCG = 0.1790
#
# Epoch 170 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 170] Loss 0.4727688431739807
# [Evaluating Epoch 170] HR = 0.2866, NDCG = 0.1905
#
# Epoch 171 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 171] Loss 0.13873687386512756
# [Evaluating Epoch 171] HR = 0.2931, NDCG = 0.2022
#
# Epoch 172 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 172] Loss 0.11319111287593842
# [Evaluating Epoch 172] HR = 0.2951, NDCG = 0.2047
#
# Epoch 173 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 173] Loss 0.14785030484199524
# [Evaluating Epoch 173] HR = 0.2973, NDCG = 0.1984
#
# Epoch 174 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 174] Loss 0.07103881984949112
# [Evaluating Epoch 174] HR = 0.2954, NDCG = 0.1794
#
# Epoch 175 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 175] Loss 0.06209569424390793
# [Evaluating Epoch 175] HR = 0.2950, NDCG = 0.1927
#
# Epoch 176 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 176] Loss 0.1618412882089615
# [Evaluating Epoch 176] HR = 0.2953, NDCG = 0.1941
#
# Epoch 177 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 177] Loss 0.15147936344146729
# [Evaluating Epoch 177] HR = 0.3013, NDCG = 0.2001
#
# Epoch 178 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 178] Loss 0.5764545202255249
# [Evaluating Epoch 178] HR = 0.2951, NDCG = 0.1961
#
# Epoch 179 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 179] Loss 0.07155345380306244
# [Evaluating Epoch 179] HR = 0.2957, NDCG = 0.1975
#
# Epoch 180 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 180] Loss 0.20863811671733856
# [Evaluating Epoch 180] HR = 0.2973, NDCG = 0.1936
#
# Epoch 181 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 181] Loss 0.5458521246910095
# [Evaluating Epoch 181] HR = 0.2980, NDCG = 0.2061
#
# Epoch 182 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 182] Loss 0.10319069027900696
# [Evaluating Epoch 182] HR = 0.2940, NDCG = 0.1836
#
# Epoch 183 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 183] Loss 0.10951777547597885
# [Evaluating Epoch 183] HR = 0.2961, NDCG = 0.1827
#
# Epoch 184 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 184] Loss 1.1641194820404053
# [Evaluating Epoch 184] HR = 0.2918, NDCG = 0.1951
#
# Epoch 185 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 185] Loss 0.4718039035797119
# [Evaluating Epoch 185] HR = 0.2940, NDCG = 0.1961
#
# Epoch 186 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 186] Loss 0.19344940781593323
# [Evaluating Epoch 186] HR = 0.3002, NDCG = 0.1883
#
# Epoch 187 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 187] Loss 1.6605823040008545
# [Evaluating Epoch 187] HR = 0.2899, NDCG = 0.1930
#
# Epoch 188 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 188] Loss 0.22442243993282318
# [Evaluating Epoch 188] HR = 0.2945, NDCG = 0.1942
#
# Epoch 189 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 189] Loss 0.15975478291511536
# [Evaluating Epoch 189] HR = 0.2912, NDCG = 0.1884
#
# Epoch 190 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 190] Loss 0.1356935054063797
# [Evaluating Epoch 190] HR = 0.2955, NDCG = 0.1914
#
# Epoch 191 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 191] Loss 0.4387770891189575
# [Evaluating Epoch 191] HR = 0.2917, NDCG = 0.1759
#
# Epoch 192 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 192] Loss 0.1837533414363861
# [Evaluating Epoch 192] HR = 0.2964, NDCG = 0.1901
#
# Epoch 193 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 193] Loss 0.501161515712738
# [Evaluating Epoch 193] HR = 0.2935, NDCG = 0.1916
#
# Epoch 194 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 194] Loss 0.14436423778533936
# [Evaluating Epoch 194] HR = 0.2961, NDCG = 0.2003
#
# Epoch 195 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 195] Loss 0.5569416880607605
# [Evaluating Epoch 195] HR = 0.2887, NDCG = 0.1951
#
# Epoch 196 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 196] Loss 0.9656952023506165
# [Evaluating Epoch 196] HR = 0.2959, NDCG = 0.1916
#
# Epoch 197 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 197] Loss 0.08561649173498154
# [Evaluating Epoch 197] HR = 0.2899, NDCG = 0.1948
#
# Epoch 198 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 198] Loss 0.514768123626709
# [Evaluating Epoch 198] HR = 0.2936, NDCG = 0.1911
#
# Epoch 199 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 199] Loss 0.062040019780397415
# [Evaluating Epoch 199] HR = 0.2915, NDCG = 0.1911

# %%
neumf_config = {'alias': 'pretrain_neumf_factor8neg4',
                'num_epoch': 200,
                'batch_size': 4,
                'optimizer': 'adam',
                'adam_lr': 1e-3,
                'num_users': num_userid,
              'num_items': num_itemid,
                'latent_dim_mf': 8,
                'latent_dim_mlp': 8,
                'num_negative': 4,
                'layers': [16,64,32,16,8],  # layers[0] is the concat of latent user vector & latent item vector
                'l2_regularization': 0.0000001,
                'use_cuda': True,
                'device_id': 0,
                'pretrain': True,
                'pretrain_mf': 'gmf_factor8neg4-implict_best.model',
                'pretrain_mlp': 'mlp_factor8neg4_bz256_166432168_pretrain_reg_0.0000001_best.model',
                'model_dir':'checkpoints/{}_Epoch{}_HR{:.4f}_NDCG{:.4f}.model'
                }

# %%
train_model(NeuMFEngine, neumf_config)
# Out:
# NeuMF(
#   (embedding_user_mlp): Embedding(11411, 8)
#   (embedding_item_mlp): Embedding(13203, 8)
#   (embedding_user_mf): Embedding(11411, 8)
#   (embedding_item_mf): Embedding(13203, 8)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (affine_output): Linear(in_features=16, out_features=1, bias=True)
#   (logistic): Sigmoid()
# )
# Epoch 0 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 0] Loss 0.2156829684972763
# /home/ec2-user/SageMaker/tdc-product-recommendation/metrics.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_in_top_k['ndcg'] = test_in_top_k['rank'].apply(lambda x: math.log(2) / math.log(1 + x)) # the rank starts from 1
# [Evaluating Epoch 0] HR = 0.2520, NDCG = 0.1753
#
# Epoch 1 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 1] Loss 0.16223248839378357
# [Evaluating Epoch 1] HR = 0.2661, NDCG = 0.1891
#
# Epoch 2 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 2] Loss 0.6058328151702881
# [Evaluating Epoch 2] HR = 0.2681, NDCG = 0.1910
#
# Epoch 3 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 3] Loss 0.21760070323944092
# [Evaluating Epoch 3] HR = 0.2789, NDCG = 0.1966
#
# Epoch 4 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 4] Loss 0.9215611219406128
# [Evaluating Epoch 4] HR = 0.2788, NDCG = 0.1975
#
# Epoch 5 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 5] Loss 0.3125734329223633
# [Evaluating Epoch 5] HR = 0.2788, NDCG = 0.1949
#
# Epoch 6 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 6] Loss 0.27422451972961426
# [Evaluating Epoch 6] HR = 0.2838, NDCG = 0.1970
#
# Epoch 7 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 7] Loss 0.053346529603004456
# [Evaluating Epoch 7] HR = 0.2802, NDCG = 0.1914
#
# Epoch 8 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 8] Loss 0.48879462480545044
# [Evaluating Epoch 8] HR = 0.2824, NDCG = 0.1966
#
# Epoch 9 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 9] Loss 0.2386084944009781
# [Evaluating Epoch 9] HR = 0.2820, NDCG = 0.1938
#
# Epoch 10 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 10] Loss 0.8320582509040833
# [Evaluating Epoch 10] HR = 0.2804, NDCG = 0.1992
#
# Epoch 11 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 11] Loss 0.4147114157676697
# [Evaluating Epoch 11] HR = 0.2825, NDCG = 0.1952
#
# Epoch 12 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 12] Loss 0.21291576325893402
# [Evaluating Epoch 12] HR = 0.2838, NDCG = 0.1944
#
# Epoch 13 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 13] Loss 0.5513538122177124
# [Evaluating Epoch 13] HR = 0.2838, NDCG = 0.1975
#
# Epoch 14 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 14] Loss 0.21093347668647766
# [Evaluating Epoch 14] HR = 0.2837, NDCG = 0.1978
#
# Epoch 15 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 15] Loss 0.09395965933799744
# [Evaluating Epoch 15] HR = 0.2930, NDCG = 0.2017
#
# Epoch 16 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 16] Loss 0.171176016330719
# [Evaluating Epoch 16] HR = 0.2890, NDCG = 0.1975
#
# Epoch 17 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 17] Loss 1.9565300941467285
# [Evaluating Epoch 17] HR = 0.2961, NDCG = 0.2041
#
# Epoch 18 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 18] Loss 0.30023515224456787
# [Evaluating Epoch 18] HR = 0.2933, NDCG = 0.2000
#
# Epoch 19 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 19] Loss 0.9747565984725952
# [Evaluating Epoch 19] HR = 0.2906, NDCG = 0.2012
#
# Epoch 20 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 20] Loss 0.5416572093963623
# [Evaluating Epoch 20] HR = 0.2860, NDCG = 0.1980
#
# Epoch 21 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 21] Loss 0.3144415318965912
# [Evaluating Epoch 21] HR = 0.2884, NDCG = 0.1998
#
# Epoch 22 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 22] Loss 0.9315137267112732
# [Evaluating Epoch 22] HR = 0.2947, NDCG = 0.2036
#
# Epoch 23 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 23] Loss 0.22434668242931366
# [Evaluating Epoch 23] HR = 0.2922, NDCG = 0.2019
#
# Epoch 24 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 24] Loss 0.2047121673822403
# [Evaluating Epoch 24] HR = 0.2909, NDCG = 0.2028
#
# Epoch 25 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 25] Loss 0.31947988271713257
# [Evaluating Epoch 25] HR = 0.2880, NDCG = 0.1988
#
# Epoch 26 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 26] Loss 0.03814481943845749
# [Evaluating Epoch 26] HR = 0.2934, NDCG = 0.2044
#
# Epoch 27 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 27] Loss 0.02073967456817627
# [Evaluating Epoch 27] HR = 0.2995, NDCG = 0.2053
#
# Epoch 28 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 28] Loss 0.07841325551271439
# [Evaluating Epoch 28] HR = 0.2949, NDCG = 0.2060
#
# Epoch 29 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 29] Loss 0.2807135581970215
# [Evaluating Epoch 29] HR = 0.2985, NDCG = 0.2072
#
# Epoch 30 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 30] Loss 0.5686382055282593
# [Evaluating Epoch 30] HR = 0.2983, NDCG = 0.1890
#
# Epoch 31 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 31] Loss 0.8401511907577515
# [Evaluating Epoch 31] HR = 0.2952, NDCG = 0.2030
#
# Epoch 32 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 32] Loss 0.6806005835533142
# [Evaluating Epoch 32] HR = 0.2955, NDCG = 0.2054
#
# Epoch 33 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 33] Loss 0.36360299587249756
# [Evaluating Epoch 33] HR = 0.2976, NDCG = 0.2070
#
# Epoch 34 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 34] Loss 0.4798350930213928
# [Evaluating Epoch 34] HR = 0.2927, NDCG = 0.2025
#
# Epoch 35 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 35] Loss 0.24886533617973328
# [Evaluating Epoch 35] HR = 0.2931, NDCG = 0.2030
#
# Epoch 36 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 36] Loss 0.2759069502353668
# [Evaluating Epoch 36] HR = 0.2952, NDCG = 0.2053
#
# Epoch 37 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 37] Loss 0.1537015289068222
# [Evaluating Epoch 37] HR = 0.2894, NDCG = 0.2007
#
# Epoch 38 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 38] Loss 0.04023774713277817
# [Evaluating Epoch 38] HR = 0.2938, NDCG = 0.2044
#
# Epoch 39 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 39] Loss 0.06634455174207687
# [Evaluating Epoch 39] HR = 0.2895, NDCG = 0.1959
#
# Epoch 40 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 40] Loss 0.058123260736465454
# [Evaluating Epoch 40] HR = 0.2905, NDCG = 0.2015
#
# Epoch 41 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 41] Loss 0.12383578717708588
# [Evaluating Epoch 41] HR = 0.2928, NDCG = 0.2043
#
# Epoch 42 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 42] Loss 0.19730304181575775
# [Evaluating Epoch 42] HR = 0.2930, NDCG = 0.2034
#
# Epoch 43 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 43] Loss 0.01983189582824707
# [Evaluating Epoch 43] HR = 0.2940, NDCG = 0.2032
#
# Epoch 44 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 44] Loss 0.46183568239212036
# [Evaluating Epoch 44] HR = 0.2928, NDCG = 0.2012
#
# Epoch 45 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 45] Loss 0.6940931081771851
# [Evaluating Epoch 45] HR = 0.2937, NDCG = 0.2028
#
# Epoch 46 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 46] Loss 0.20783080160617828
# [Evaluating Epoch 46] HR = 0.2884, NDCG = 0.2014
#
# Epoch 47 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 47] Loss 0.061200037598609924
# [Evaluating Epoch 47] HR = 0.2900, NDCG = 0.2000
#
# Epoch 48 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 48] Loss 0.11163555085659027
# [Evaluating Epoch 48] HR = 0.2885, NDCG = 0.1972
#
# Epoch 49 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 49] Loss 0.8130155801773071
# [Evaluating Epoch 49] HR = 0.2872, NDCG = 0.1989
#
# Epoch 50 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 50] Loss 0.22415882349014282
# [Evaluating Epoch 50] HR = 0.2902, NDCG = 0.2039
#
# Epoch 51 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 51] Loss 0.2501244843006134
# [Evaluating Epoch 51] HR = 0.2906, NDCG = 0.2009
#
# Epoch 52 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 52] Loss 0.20359793305397034
# [Evaluating Epoch 52] HR = 0.2975, NDCG = 0.2076
#
# Epoch 53 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 53] Loss 0.5663698315620422
# [Evaluating Epoch 53] HR = 0.2848, NDCG = 0.2005
#
# Epoch 54 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 54] Loss 0.3109648823738098
# [Evaluating Epoch 54] HR = 0.2873, NDCG = 0.1994
#
# Epoch 55 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 55] Loss 0.11868445575237274
# [Evaluating Epoch 55] HR = 0.2810, NDCG = 0.1938
#
# Epoch 56 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 56] Loss 0.30572938919067383
# [Evaluating Epoch 56] HR = 0.2845, NDCG = 0.1979
#
# Epoch 57 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 57] Loss 0.1960608959197998
# [Evaluating Epoch 57] HR = 0.2886, NDCG = 0.1997
#
# Epoch 58 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 58] Loss 0.3328531086444855
# [Evaluating Epoch 58] HR = 0.2877, NDCG = 0.1991
#
# Epoch 59 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 59] Loss 0.31161004304885864
# [Evaluating Epoch 59] HR = 0.2877, NDCG = 0.1997
#
# Epoch 60 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 60] Loss 0.6969987154006958
# [Evaluating Epoch 60] HR = 0.2841, NDCG = 0.1941
#
# Epoch 61 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 61] Loss 0.42231395840644836
# [Evaluating Epoch 61] HR = 0.2904, NDCG = 0.2027
#
# Epoch 62 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 62] Loss 0.1114688292145729
# [Evaluating Epoch 62] HR = 0.2862, NDCG = 0.1947
#
# Epoch 63 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 63] Loss 0.24786576628684998
# [Evaluating Epoch 63] HR = 0.2830, NDCG = 0.1971
#
# Epoch 64 starts !
# ----------------------------------------------------------------------
# [Training Stage Epoch 64] Loss 0.05039684846997261
# [Evaluating Epoch 64] HR = 0.2863, NDCG = 0.1866
#
# Epoch 65 starts !
# ----------------------------------------------------------------------

# %%
print('Done!')

# %%
neumf_config_d = {'alias': 'pretrain_neumf_factor8neg4',
                'num_epoch': 200,
                'batch_size': 4,
                'optimizer': 'adam',
                'adam_lr': 1e-3,
                'num_users': num_userid,
              'num_items': num_itemid,
                'latent_dim_mf': 8,
                'latent_dim_mlp': 8,
                'num_negative': 4,
                'layers': [16,64,32,16,8],  # layers[0] is the concat of latent user vector & latent item vector
                'l2_regularization': 0.0000001,
                'use_cuda': False,
                'device_id': 0,
                'pretrain': True,
                'pretrain_mf': 'gmf_factor8neg4-implict_best.model',
                'pretrain_mlp': 'mlp_factor8neg4_bz256_166432168_pretrain_reg_0.0000001_best.model',
                'model_dir':'checkpoints/{}_Epoch{}_HR{:.4f}_NDCG{:.4f}.model'
                }

# %%
model=NeuMFEngine(neumf_config_d)
# Out:
# NeuMF(
#   (embedding_user_mlp): Embedding(11411, 8)
#   (embedding_item_mlp): Embedding(13203, 8)
#   (embedding_user_mf): Embedding(11411, 8)
#   (embedding_item_mf): Embedding(13203, 8)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (affine_output): Linear(in_features=16, out_features=1, bias=True)
#   (logistic): Sigmoid()
# )
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-96cea64fccd9> in <module>()
# ----> 1 model=NeuMFEngine(neumf_config_d)
#
# ~/SageMaker/tdc-product-recommendation/model/neumf.py in __init__(self, config)
#      85
#      86         if config['pretrain']:
# ---> 87             self.model.load_pretrain_weights()
#
# ~/SageMaker/tdc-product-recommendation/model/neumf.py in load_pretrain_weights(self)
#      55         if config['use_cuda'] is True:
#      56             mlp_model.cuda()
# ---> 57         resume_checkpoint(mlp_model, model_dir=config['pretrain_mlp'], device_id=config['device_id'])
#      58
#      59         self.embedding_user_mlp.weight.data = mlp_model.embedding_user.weight.data
#
# ~/SageMaker/tdc-product-recommendation/utils.py in resume_checkpoint(model, model_dir, device_id)
#      12 def resume_checkpoint(model, model_dir, device_id):
#      13     state_dict = torch.load(model_dir,
# ---> 14                             map_location=lambda storage, loc: storage.cuda(device=device_id))  # ensure all storage are on gpu
#      15     model.load_state_dict(state_dict)
#      16
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     366         f = open(f, 'rb')
#     367     try:
# --> 368         return _load(f, map_location, pickle_module)
#     369     finally:
#     370         if new_fd:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/serialization.py in _load(f, map_location, pickle_module)
#     540     unpickler = pickle_module.Unpickler(f)
#     541     unpickler.persistent_load = persistent_load
# --> 542     result = unpickler.load()
#     543
#     544     deserialized_storage_keys = pickle_module.load(f)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/serialization.py in persistent_load(saved_id)
#     503             if root_key not in deserialized_objects:
#     504                 deserialized_objects[root_key] = restore_location(
# --> 505                     data_type(size), location)
#     506             storage = deserialized_objects[root_key]
#     507             if view_metadata is not None:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/serialization.py in restore_location(storage, location)
#     389     else:
#     390         def restore_location(storage, location):
# --> 391             result = map_location(storage, location)
#     392             if result is None:
#     393                 result = default_restore_location(storage, location)
#
# ~/SageMaker/tdc-product-recommendation/utils.py in <lambda>(storage, loc)
#      12 def resume_checkpoint(model, model_dir, device_id):
#      13     state_dict = torch.load(model_dir,
# ---> 14                             map_location=lambda storage, loc: storage.cuda(device=device_id))  # ensure all storage are on gpu
#      15     model.load_state_dict(state_dict)
#      16
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, non_blocking, **kwargs)
#      66         if device is None:
#      67             device = -1
# ---> 68     with torch.cuda.device(device):
#      69         if self.is_sparse:
#      70             new_type = getattr(torch.cuda.sparse, self.__class__.__name__)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/cuda/__init__.py in __enter__(self)
#     224         if self.idx == -1:
#     225             return
# --> 226         self.prev_idx = torch._C._cuda_getDevice()
#     227         if self.prev_idx != self.idx:
#     228             torch._C._cuda_setDevice(self.idx)
#
# RuntimeError: cuda runtime error (38) : no CUDA-capable device is detected at /opt/conda/conda-bld/pytorch_1549281116128/work/torch/csrc/cuda/Module.cpp:53
